# %%
import requests
from bs4 import BeautifulSoup

# URL of Supreme Court of India's recent judgments page
URL = "https://www.livelaw.in/articles/"  # Update with the exact URL if needed

def get_supreme_court_cases():
    response = requests.get(URL)

    if response.status_code != 200:
        print(f"Failed to fetch page: {response.status_code}")
        return []

    soup = BeautifulSoup(response.text, "html.parser")
    # print(soup)
    first_div = soup.find_all("div", class_="sup_crt_col_border_bottom grid_page")
    for div in first_div:
        # Find all <a> tags inside the div
        a_tags = div.find_all("a", href=True)

        for a in a_tags:
            href = a["href"]
            full_link = f"https://www.livelaw.in{href}" if href.startswith("/") else href
            print(full_link)
            break

if __name__ == "__main__":
    for i in range(10):
      if i>0: URL+=f"{i}"
      case_data = get_supreme_court_cases()
# Out:
# https://www.livelaw.in/articles/supreme-court-judgment-x-vs-state-of-rajasthan-grant-of-bail-rape-cases-critical-analysis-285733
# https://www.livelaw.in/articles/law-dying-declarations-india-bad-law-285657
# https://www.livelaw.in/articles/doctrine-of-forum-non-conveniens-comparative-analysis-between-india-and-united-states-285577
# https://www.livelaw.in/articles/differently-abled-people-accessibility-challenges-and-buildings-universal-design-285364
# https://www.livelaw.in/articles/sir-jamshedji-behramji-kanga-life-and-legacy-285091
# https://www.livelaw.in/articles/sanction-to-prosecute-public-servants-section-197-crpc-vs-section-218-bnss-285065
# https://www.livelaw.in/articles/right-to-marry-and-same-sex-marriage-in-india-285011
# https://www.livelaw.in/articles/ks-puttuswamy-judgment-and-right-to-be-forgotten-284853
# https://www.livelaw.in/articles/to-speak-or-not-to-speak-understanding-thethin-line-between-free-speech-and-obscenity-284427
# ...

# %% [markdown]
# https://www.livelaw.in/gsearch?q=murder#gsc.tab=0&gsc.q=murder&gsc.sort=date&gsc.page=1

# %% [markdown]
# For article content

# %%
import requests
from bs4 import BeautifulSoup

def scrape_livelaw_article(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to retrieve the article. Status code: {response.status_code}")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')

    article_content = ""
    article_body = soup.find('div', class_='details-story-wrapper')  # Adjust the class name if necessary
    paragraphs = article_body.find_all('p')
    for para in paragraphs:
        article_content += para.get_text(strip=True) + "\n"
    return article_content

query="murder"
URL = f"https://www.livelaw.in/tags/{query}/"  # Update with the exact URL if needed

def get_supreme_court_cases():
    response = requests.get(URL)

    if response.status_code != 200:
        print(f"Failed to fetch page: {response.status_code}")
        return []

    soup = BeautifulSoup(response.text, "html.parser")
    first_div = soup.find_all("div", class_="author_article_content")
    for div in first_div:
        a_tags = div.find_all("a", href=True)

        for a in a_tags:
            href = a["href"]
            full_link = f"https://www.livelaw.in{href}" if href.startswith("/") else href
            # print(full_link)
            content=scrape_livelaw_article(full_link)
            if content==None: continue
            print(content)
            break

if __name__ == "__main__":
    for i in range(1):
      if i>0: URL+=f"page-{i}"
      case_data = get_supreme_court_cases()
# Out:
# The Delhi High Court on Tuesday granted regular bail to wrestler Sushil Kumar in relation to the case of murder of 27-year-old former junior national wrestling champion Sagar Dhankar in May 2021.Justice Sanjeev Narula passed the order granting bail to Kumar, who has been lodged in Tihar jail in the case. The Court has granted bail to Kumar on a bail bond of Rs. 50,000 and two sureties of...
#
# The Delhi High Court has ruled that the trial proceedings of a child alleged to be in conflict with law and an adult offender cannot be held jointly after a preliminary assessment of Juvenile Justice Board (JJB) is done declaring the child in conflict with law to be psychologically and physically mature.“Therefore, in the opinion of this Court, as per plain reading of Section 23 of JJ Act,...
#
# ...

# %%
import requests
from bs4 import BeautifulSoup

def scrape_livelaw_article(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to retrieve the article. Status code: {response.status_code}")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')

    # Extracting article content
    article_content = ""
    article_body = soup.find('div', class_='details-story-wrapper')  # Adjust the class name if necessary
    # print(article_body)
    # for div in article_body:
        # Find all <a> tags inside the div
    paragraphs = article_body.find_all('p')
    for para in paragraphs:
        article_content += para.get_text(strip=True) + "\n"
    # if article_body:
    #     paragraphs = article_body.find_all('p')
    #     for para in paragraphs:
    #         article_content += para.get_text(strip=True) + "\n"
    # else:
    #     print("Could not find the article content.")
    #     return None
    # print(article_content)
    return article_content

if __name__ == "__main__":
    url = "https://www.livelaw.in/high-court/kerala-high-court/kerala-high-court-depression-section-84-ipc-legal-insanity-unsoundness-of-mind-defence-for-murder-273433"
    article_text = scrape_livelaw_article(url)
    if article_text:
        print(article_text)
# Out:
# The Kerala High Court recently denied the plea of 'legal insanity' raised by a woman sentenced to life for murdering her twelve-year-old nephew, holding that depression would not come under purview of Section 84 IPC unless there is material to show that it significantly impaired the ability to distinguish right from wrong.The Division Bench of Justice Raja Vijayaraghavan V and Justice...

# %% [markdown]
# For article heading

# %%
import requests
from bs4 import BeautifulSoup

def scrape_livelaw_article(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to retrieve the article. Status code: {response.status_code}")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')

    article_heading = ""
    heading_tag = soup.find('h1')  # Adjust if the heading tag differs
    if heading_tag:
        article_heading = heading_tag.get_text(strip=True)
    else:
        print("Could not find the article heading.")
        return None

    return article_heading

query="murder"
URL = f"https://www.livelaw.in/tags/{query}/"

def get_supreme_court_cases():
    response = requests.get(URL)

    if response.status_code != 200:
        print(f"Failed to fetch page: {response.status_code}")
        return []

    soup = BeautifulSoup(response.text, "html.parser")
    first_div = soup.find_all("div", class_="author_article_content")
    for div in first_div:
        a_tags = div.find_all("a", href=True)

        for a in a_tags:
            href = a["href"]
            full_link = f"https://www.livelaw.in{href}" if href.startswith("/") else href
            # print(full_link)
            content=scrape_livelaw_article(full_link)
            if content==None: continue
            print(content)
            break

if __name__ == "__main__":
    for i in range(1):
      if i>0: URL+=f"page-{i}"
      case_data = get_supreme_court_cases()
# Out:
# Delhi High Court Grants Bail To Wrestler Sushil Kumar In Sagar Dhankar Murder Case
# Child In Conflict With Law Being Treated As Adult Can't Be Tried Jointly With Adult Offender: Delhi High Court
# 1984 Anti Sikh Riots: Delhi Court Awards Life Sentence To Former Congress MP Sajjan Kumar In Murder Case
# Mental Health Act Bars Punishing Persons For Offences Committed While Attempting Suicide : Kerala High Court
# State Withdrawing Such Cases Sends Wrong Message To Society: Calcutta HC Orders Fresh Trial In Ten Criminal Cases Tied To Nandigram Unrest
# Delhi Riots: High Court Issues Notice On Tahir Hussain's Bail Plea In IB Staffer Ankit Sharma's Murder Case
# Mother Of SFI Leader Abhimanyu Who Was Stabbed To Death In 2018 Over Campus Political Rivalry Moves Kerala High Court Citing Delay In Trial
# 'Accused Acquitted Due To Shortfalls In Probe': Kerala HC Calls For Scientific Investigation Methods, Centralized Knowledge Repository
# ...

# %% [markdown]
# TOI scraping

# %%
import requests
from bs4 import BeautifulSoup

def scrape_livelaw_article(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to retrieve the article. Status code: {response.status_code}")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')

    article_content = ""
    article_body = soup.find('div', class_='_s30J')  # Adjusted div class
    if article_body:
        paragraphs = article_body.find_all('br')  # Extracting text separated by <br>
        for para in article_body.find_all(text=True, recursive=False):
            article_content += para.strip() + "\n"
    else:
        print("Could not find the article content.")
    return article_content

def scrape_toi_article(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to retrieve the article. Status code: {response.status_code}")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')

    article_content = ""
    first_div = soup.find_all('div', class_='crmK8')  # Adjust the class name if necessary
    # print(first_div)
    for div in first_div:
        # Find all <a> tags inside the div
        a_tags = div.find_all("a", href=True)

        for a in a_tags[:5]:
            href = a["href"]
            full_link = f"https://www.livelaw.in{href}" if href.startswith("/") else href
            print(full_link)
            content=scrape_livelaw_article(full_link)
            if content==None: continue
            print(content)
            # break
    return article_content
    # Extracting article heading
    # article_heading = ""
    # heading_tag = soup.find('h1')  # Adjust if the heading tag differs
    # if heading_tag:
    #     article_heading = heading_tag.get_text(strip=True)
    # else:
    #     print("Could not find the article heading.")
    #     return None

    # return article_heading

if __name__ == "__main__":
    topic="Over Speed & High Speed Are Relative Terms, Driving At High Speed By Itself Doesn't Mean Accused Was Rash Or Negligent: Kerala High Court"
    url = f"https://timesofindia.indiatimes.com/topic/{topic}/news"
    article_heading = scrape_toi_article(url)
    if article_heading:
        print(article_heading)
# Out:
# https://timesofindia.indiatimes.com/city/bhopal/metro-chugs-towards-completion-with-trial-run-from-rkmp-to-aiims/articleshow/118743142.cms
# <ipython-input-61-8312add82f34>:17: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   for para in article_body.find_all(text=True, recursive=False):
# Bhopal: A
#
# trial run
#
# of the
#
# Bhopal Metro
#
# train from Rani Kamlapati Railway Station to
#
# AIIMS Bhopal
#
# station was conducted on Tuesday, marking a significant step towards the project's completion.
# Madhya Pradesh Metro Rail Corporation Limited
#
# (MPMRCL) oversaw the test run, which utilized the newly completed Railway over Bridge (RoB) connecting AIIMS Bhopal to Habibganj.
# The train traveled through DRM Office and Alkapuri stations, operating at speeds between 10 and 20 km per hour. Future trials will gradually increase the train speed to its maximum design capacity of 90 km per hour.
# Passenger operations
#
# ...
